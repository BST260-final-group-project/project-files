# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.special import boxcox1p
from sklearn import preprocessing

plt.style.use('ggplot')

# %%
data = pd.read_csv("feature_JJC_fillna_scale.csv")
data_scaled = pd.DataFrame()
data_scaled["Id"] = data["Id"]
data_scaled["source"] = data["source"]
data_scaled["SalePrice"] = data["SalePrice"]

# %%
data.columns
# Out:
# Index([u'Id', u'source', u'SalePrice', u'1stFlrSF', u'2ndFlrSF', u'3SsnPorch',
#        u'Alley', u'BedroomAbvGr', u'BldgType', u'BsmtCond', u'BsmtExposure',
#        u'BsmtFinSF1', u'BsmtFinSF2', u'BsmtFinType1', u'BsmtFinType2',
#        u'BsmtFullBath', u'BsmtHalfBath', u'BsmtQual', u'BsmtUnfSF',
#        u'CentralAir', u'Condition1', u'Condition2', u'Electrical'],
#       dtype='object')

# %% [markdown]
# # 1stFlrSF

# %%
feature = "1stFlrSF"
# Check the distribution 
sns.distplot(data[feature])

# %%
# Box-cox transform
lam = 0.01
data_scaled[feature] = preprocessing.scale(boxcox1p(data[feature], lam))

# Check the new distribution
sns.distplot(data_scaled[feature])

# %% [markdown]
# # 2ndFlrSF

# %%
feature = "2ndFlrSF"
# Check the distribution 
sns.distplot(data[feature])

# %%
# Box-cox transform
lam = 0.05
data_scaled[feature] = preprocessing.scale(data[feature])

# Check the new distribution
sns.distplot(data_scaled[feature])
# Out:
# /Users/jianghanyu/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, _DataConversionWarning)

# %% [markdown]
# # 3SsnPorch

# %%
feature = "3SsnPorch"
# Check the distribution 
sns.distplot(data[feature])

# %%
# Box-cox transform
lam = 0.05
data_scaled[feature] = preprocessing.scale(data[feature])

# Check the new distribution
sns.distplot(data_scaled[feature])

# %% [markdown]
# # Alley

# %%
np.sum(data["Alley"].isnull())
# Out:
# 2721

# %%
data["Alley"] = data["Alley"].fillna("None")

# %%
data_scaled["Alley"] = data["Alley"]

# %% [markdown]
# # BedroomAbvGr

# %%
np.sum(data["BedroomAbvGr"].isnull())
# Out:
# 0

# %%
feature = "BedroomAbvGr"
# Check the distribution 
sns.distplot(data[feature])

# %%
data_scaled[feature] = data[feature]

# %% [markdown]
# # BldgType

# %%
np.sum(data["BldgType"].isnull())
# Out:
# 0

# %%
data_scaled["BldgType"] = data["BldgType"]

# %% [markdown]
# # BsmtCond

# %%
# Covert "BsmtCond" from categorical to ordinal 
map_BsmtCond = {"Ex":5, "Gd":4, "TA":3, "Fa":2, "Po":1, "NA":0}
data["BsmtCond"] = data["BsmtCond"].fillna("NA")
data_scaled["BsmtCond"] = [map_BsmtCond[x] for x in data["BsmtCond"]]

# %%
np.sum(data_scaled["BsmtCond"].isnull())
# Out:
# 0

# %% [markdown]
# # BsmtExposure

# %%
# Covert "BsmtExposure" from categorical to ordinal 
map_BsmtExposure = {"Gd":4, "Av":3, "Mn":2, "No":1, "NA":0}
data["BsmtExposure"] = data["BsmtExposure"].fillna("NA")
data_scaled["BsmtExposure"] = [map_BsmtExposure[x] for x in data["BsmtExposure"]]

# %% [markdown]
# # BsmtFinSF1

# %%
feature = "BsmtFinSF1"
# Check the distribution 
sns.distplot(data[feature])

# %%
# Box-cox transform
lam = 0.15
data_scaled[feature] = preprocessing.scale(boxcox1p(data[feature], lam))

# Check the new distribution
sns.distplot(data_scaled[feature]) # Doesn't work

# %% [markdown]
# # BsmtFinSF2

# %%
feature = "BsmtFinSF2"
# Check the distribution 
data[feature] = data[feature].fillna(0)
sns.distplot(data[feature])

# %%
# Box-cox transform
lam = 0.15
data_scaled[feature] = preprocessing.scale(boxcox1p(data[feature], lam))

# Check the new distribution
sns.distplot(data_scaled[feature]) # Doesn't work

# %% [markdown]
# # BsmtFinType1

# %%
# Covert "BsmtFinType1" from categorical to ordinal 
map_BsmtFinType1 = {"GLQ":6, "ALQ":5, "BLQ":4, "Rec":3, "LwQ":2, "Unf":1, "NA":0}
data["BsmtFinType1"] = data["BsmtFinType1"].fillna("NA")
data_scaled["BsmtFinType1"] = [map_BsmtFinType1[x] for x in data["BsmtFinType1"]]

# %% [markdown]
# # BsmtFinType2

# %%
# Covert "BsmtFinType2" from categorical to ordinal 
map_BsmtFinType2 = {"GLQ":6, "ALQ":5, "BLQ":4, "Rec":3, "LwQ":2, "Unf":1, "NA":0}
data["BsmtFinType2"] = data["BsmtFinType2"].fillna("NA")
data_scaled["BsmtFinType2"] = [map_BsmtFinType2[x] for x in data["BsmtFinType2"]]

# %% [markdown]
# # BsmtFullBath

# %%
np.sum(data["BsmtFullBath"].isnull())
# Out:
# 0

# %%
data_scaled["BsmtFullBath"] = data["BsmtFullBath"]

# %% [markdown]
# # BsmtHalfBath

# %%
np.sum(data["BsmtHalfBath"].isnull())
# Out:
# 0

# %%
data_scaled["BsmtHalfBath"] = data["BsmtHalfBath"]

# %% [markdown]
# # BsmtQual

# %%
# Covert "BsmtQual" from categorical to ordinal 
map_BsmtQual = {"Ex":5, "Gd":4, "TA":3, "Fa":2, "Po":1, "NA":0}
data["BsmtQual"] = data["BsmtQual"].fillna("NA")
data_scaled["BsmtQual"] = [map_BsmtQual[x] for x in data["BsmtQual"]]

# %% [markdown]
# # BsmtUnfSF

# %%
feature = "BsmtUnfSF"
# Check the distribution 
sns.distplot(data[feature])

# %%
# Box-cox transform
lam = 0.35
data_scaled[feature] = preprocessing.scale(boxcox1p(data[feature], lam))

# Check the new distribution
sns.distplot(data_scaled[feature])

# %% [markdown]
# # CentralAir

# %%
feature = "CentralAir"
data_scaled[feature] = data[feature]

# %% [markdown]
# # Condition1

# %%
feature = "Condition1"
data_scaled[feature] = data[feature]

# %% [markdown]
# # Condition2

# %%
feature = "Condition2"
data_scaled[feature] = data[feature]

# %% [markdown]
# # Electrical

# %%
feature = "Electrical"
data_scaled[feature] = data[feature]

# %%
data_scaled.columns
# Out:
# Index([u'Id', u'source', u'SalePrice', u'1stFlrSF', u'2ndFlrSF', u'3SsnPorch',
#        u'Alley', u'BedroomAbvGr', u'BldgType', u'BsmtCond', u'BsmtExposure',
#        u'BsmtFinSF1', u'BsmtFinSF2', u'BsmtFinType1', u'BsmtFinType2',
#        u'BsmtFullBath', u'BsmtHalfBath', u'BsmtQual', u'BsmtUnfSF',
#        u'CentralAir', u'Condition1', u'Condition2', u'Electrical'],
#       dtype='object')

# %%
# Save data
data_scaled.to_csv("feature_JJC_fillna_scale2.csv", index = False)
